# %%
import gc
import numpy as np
import pandas as pd
import xgboost as xgb
from tqdm.notebook import tqdm
BASE = '../data/'

def smape(y_true, y_pred):
    smap = np.zeros(len(y_true))
    
    num = np.abs(y_true - y_pred)
    dem = ((np.abs(y_true) + np.abs(y_pred)) / 2)
    
    pos_ind = (y_true != 0) | (y_pred != 0)
    smap[pos_ind] = num[pos_ind] / dem[pos_ind]
    
    return 100 * np.mean(smap)

def vsmape(y_true, y_pred):
    smap = np.zeros(len(y_true))
    
    num = np.abs(y_true - y_pred)
    dem = ((np.abs(y_true) + np.abs(y_pred)) / 2)
    
    pos_ind = (y_true != 0) | (y_pred != 0)
    smap[pos_ind] = num[pos_ind] / dem[pos_ind]
    
    return 100 * smap

# %%
# raw = pd.read_csv("../preprocess/boosting_preprocess_neighbor.csv")
raw  = pd.read_csv("../data/preprocessing.csv")
features = ['state_i',
 'mbd_lag_1',
 'act_lag_1',
 'mbd_lag_2',
 'act_lag_2',
 'mbd_lag_3',
 'act_lag_3',
 'mbd_rollmea2_1',
 'mbd_rollmea4_1',
 'mbd_rollmea6_1',
 'neighbor_average',
 'pct_bb',
 'pct_college',
 'pct_foreign_born',
 'pct_it_workers',
 'median_hh_inc']

# %%
# feature selection

def feature_select_pearson(train, features, top_n=10):
    """
    Use Pearson coefficient for correlation feature selection
    :param train: train_set
    :param test: test_set
    :return: train_set and test_set after the feature selection
    """
    print('feature_select...')
    featureSelect = features[:]

    # Remove features with more than 0.99 missing values
    for fea in features:
        if train[fea].isnull().sum() / train.shape[0] >= 0.99:
            featureSelect.remove(fea)

    # perform Pearson correlation calculation
    corr = []
    for fea in featureSelect:
        corr.append(abs(train[[fea, 'microbusiness_density']].fillna(0).corr().values[0][1]))

    # select the top 5 features for modeling (the selection number is flexible)
    se = pd.Series(corr, index=featureSelect).sort_values(ascending=False)
    feature_select = ['mbd_lag_1'] + se[:top_n].index.tolist()
    feature_select = list(set(feature_select)) # unique values
    print('done')
    return train.drop([item for item in features if item not in feature_select], axis=1), feature_select

# %%
from sklearn import preprocessing
lbl = preprocessing.LabelEncoder()
raw['neighbor_average'] = lbl.fit_transform(raw['neighbor_average'].astype(str))# transform the wrong value into string format

# %%
import copy
# Select the optimal number of features for fitting
# find out the best number of features
best_n_top = 5
best_smape = 10000
for n_top in range(5, len(features)+1):
    feature_selection_set, tmp_features = copy.deepcopy(feature_select_pearson(raw, features, n_top))
    print(f"tmp features: {tmp_features}")
# ACT_THR :actual threshold
# ABS_THR: abstract threshold
    ACT_THR = 1.8
    ABS_THR = 1.00
    feature_selection_set['ypred_last'] = np.nan
    feature_selection_set['ypred'] = np.nan
    feature_selection_set['k'] = 1.
    VAL = []
    BEST_ROUNDS = []
    for TS in range(29, 32):
        print(TS)
    # add xgb.set_config to avoid early stopping malfunction
        xgb.set_config(verbosity=0)
        model = xgb.XGBRegressor(
            objective='reg:pseudohubererror',
            #objective='reg:squarederror',
            tree_method="hist",
            n_estimators=500,
            learning_rate=0.075,
            max_leaves = 17,
            subsample=0.50,
            colsample_bytree=0.50,
            max_bin=4096,
            n_jobs=2,
            eval_metric='mae',
            early_stopping_rounds=70,
        )

        train_indices = (feature_selection_set.istest==0) & (feature_selection_set.dcount  < TS) & (feature_selection_set.dcount >= 1) & (feature_selection_set.lastactive>ACT_THR)  & (feature_selection_set.lasttarget>ABS_THR) 
        valid_indices = (feature_selection_set.istest==0) & (feature_selection_set.dcount == TS)
        model.fit(
            feature_selection_set.loc[train_indices, tmp_features],
            feature_selection_set.loc[train_indices, 'target'].clip(-0.0043, 0.0045),
            eval_set=[(feature_selection_set.loc[valid_indices, tmp_features], feature_selection_set.loc[valid_indices, 'target'])],
            verbose=50,
        )
        best_rounds = model.best_iteration
        BEST_ROUNDS.append(model.best_iteration)
        ypred = model.predict(feature_selection_set.loc[valid_indices, tmp_features])
        feature_selection_set.loc[valid_indices, 'k'] = ypred + 1
        feature_selection_set.loc[valid_indices,'k'] = feature_selection_set.loc[valid_indices,'k'] * feature_selection_set.loc[valid_indices,'microbusiness_density']

        # Validate
        lastval = feature_selection_set.loc[feature_selection_set.dcount==TS, ['cfips', 'microbusiness_density']].set_index('cfips').to_dict()['microbusiness_density']
        dt = feature_selection_set.loc[feature_selection_set.dcount==TS, ['cfips', 'k']].set_index('cfips').to_dict()['k']

        df = feature_selection_set.loc[feature_selection_set.dcount==(TS+1), ['cfips', 'microbusiness_density', 'state', 'lastactive', 'mbd_lag_1']].reset_index(drop=True)
        df['pred'] = df['cfips'].map(dt)
        df['lastval'] = df['cfips'].map(lastval)

        df.loc[df['lastactive']<=ACT_THR, 'pred'] = df.loc[df['lastactive']<=ACT_THR, 'lastval']
        df.loc[df['lastval']<=ABS_THR, 'pred'] = df.loc[df['lastval']<=ABS_THR, 'lastval']
        feature_selection_set.loc[feature_selection_set.dcount==(TS+1), 'ypred'] = df['pred'].values
        feature_selection_set.loc[feature_selection_set.dcount==(TS+1), 'ypred_last'] = df['lastval'].values

        print(f'TS: {TS}')
        print('Last Value SMAPE:', smape(df['microbusiness_density'], df['lastval']) )
        print('XGB SMAPE:', smape(df['microbusiness_density'], df['pred']))
    
    cur_smape = smape(df['microbusiness_density'], df['pred'])
    print(f"n_top: {n_top}")
    print(f"current smape: {cur_smape}")
    print(f"best smape: {best_smape}")
    if n_top == 5:
        best_smape = cur_smape
    elif cur_smape < best_smape:
        best_smape = cur_smape
        best_n_top = n_top
        print("best_smape updated!")
            
    del feature_selection_set
    del tmp_features
# Out:
# feature_select...
# done
# tmp features: ['pct_college', 'pct_it_workers', 'pct_bb', 'mbd_lag_1', 'pct_foreign_born', 'median_hh_inc']
# 29
# [0]	validation_0-mae:0.45135
# [50]	validation_0-mae:0.01316
# [100]	validation_0-mae:0.01090
# [150]	validation_0-mae:0.01091
# [200]	validation_0-mae:0.01092
# [250]	validation_0-mae:0.01092
# [300]	validation_0-mae:0.01092
# [350]	validation_0-mae:0.01092
# [400]	validation_0-mae:0.01092
# [450]	validation_0-mae:0.01093
# [499]	validation_0-mae:0.01093
# TS: 29
# Last Value SMAPE: 1.0868726017655663
# XGB SMAPE: 1.0897397358896264
# 30
# [0]	validation_0-mae:0.44530
# [50]	validation_0-mae:0.01204
# [100]	validation_0-mae:0.01312
# [150]	validation_0-mae:0.01318
# [200]	validation_0-mae:0.01318
# [250]	validation_0-mae:0.01318
# [300]	validation_0-mae:0.01317
# [350]	validation_0-mae:0.01317
# [400]	validation_0-mae:0.01317
# [450]	validation_0-mae:0.01318
# [499]	validation_0-mae:0.01317
# TS: 30
# Last Value SMAPE: 1.318087470449913
# XGB SMAPE: 1.304298884208811
# 31
# [0]	validation_0-mae:0.45100
# [50]	validation_0-mae:0.01346
# [100]	validation_0-mae:0.01118
# [150]	validation_0-mae:0.01118
# [200]	validation_0-mae:0.01118
# [250]	validation_0-mae:0.01117
# [300]	validation_0-mae:0.01117
# [350]	validation_0-mae:0.01117
# [400]	validation_0-mae:0.01117
# [450]	validation_0-mae:0.01117
# [499]	validation_0-mae:0.01117
# TS: 31
# Last Value SMAPE: 1.1258309832479911
# XGB SMAPE: 1.1136232718946462
# n_top: 5
# current smape: 1.1136232718946462
# best smape: 10000
# feature_select...
# done
# tmp features: ['pct_college', 'pct_it_workers', 'pct_bb', 'mbd_lag_1', 'pct_foreign_born', 'neighbor_average', 'median_hh_inc']
# 29
# [0]	validation_0-mae:0.45135
# [50]	validation_0-mae:0.01316
# [100]	validation_0-mae:0.01089
# [150]	validation_0-mae:0.01091
# [200]	validation_0-mae:0.01092
# [250]	validation_0-mae:0.01092
# [300]	validation_0-mae:0.01092
# [350]	validation_0-mae:0.01093
# [400]	validation_0-mae:0.01093
# [450]	validation_0-mae:0.01093
# [499]	validation_0-mae:0.01093
# TS: 29
# Last Value SMAPE: 1.0868726017655663
# XGB SMAPE: 1.0901043960795216
# 30
# [0]	validation_0-mae:0.44530
# [50]	validation_0-mae:0.01204
# [100]	validation_0-mae:0.01312
# [150]	validation_0-mae:0.01318
# [200]	validation_0-mae:0.01318
# [250]	validation_0-mae:0.01318
# [300]	validation_0-mae:0.01318
# [350]	validation_0-mae:0.01318
# [400]	validation_0-mae:0.01318
# [450]	validation_0-mae:0.01319
# [499]	validation_0-mae:0.01319
# TS: 30
# Last Value SMAPE: 1.318087470449913
# XGB SMAPE: 1.3054785825427364
# 31
# [0]	validation_0-mae:0.45100
# [50]	validation_0-mae:0.01346
# [100]	validation_0-mae:0.01118
# [150]	validation_0-mae:0.01118
# [200]	validation_0-mae:0.01118
# [250]	validation_0-mae:0.01117
# [300]	validation_0-mae:0.01117
# [350]	validation_0-mae:0.01117
# [400]	validation_0-mae:0.01117
# [450]	validation_0-mae:0.01117
# [499]	validation_0-mae:0.01117
# TS: 31
# Last Value SMAPE: 1.1258309832479911
# XGB SMAPE: 1.1137830089578054
# n_top: 6
# current smape: 1.1137830089578054
# best smape: 1.1136232718946462
# feature_select...
# done
# tmp features: ['pct_college', 'pct_it_workers', 'pct_bb', 'mbd_lag_1', 'pct_foreign_born', 'neighbor_average', 'median_hh_inc', 'act_lag_3']
# 29
# [0]	validation_0-mae:0.45135
# [50]	validation_0-mae:0.01315
# [100]	validation_0-mae:0.01090
# [150]	validation_0-mae:0.01095
# [200]	validation_0-mae:0.01096
# [250]	validation_0-mae:0.01097
# [300]	validation_0-mae:0.01097
# [350]	validation_0-mae:0.01098
# [400]	validation_0-mae:0.01099
# [450]	validation_0-mae:0.01100
# [499]	validation_0-mae:0.01100
# TS: 29
# Last Value SMAPE: 1.0868726017655663
# XGB SMAPE: 1.0977864998274134
# 30
# [0]	validation_0-mae:0.44530
# [50]	validation_0-mae:0.01202
# [100]	validation_0-mae:0.01312
# [150]	validation_0-mae:0.01319
# [200]	validation_0-mae:0.01319
# [250]	validation_0-mae:0.01319
# [300]	validation_0-mae:0.01320
# [350]	validation_0-mae:0.01320
# [400]	validation_0-mae:0.01320
# [450]	validation_0-mae:0.01320
# [499]	validation_0-mae:0.01320
# TS: 30
# Last Value SMAPE: 1.318087470449913
# XGB SMAPE: 1.3063562087539113
# 31
# [0]	validation_0-mae:0.45100
# [50]	validation_0-mae:0.01347
# [100]	validation_0-mae:0.01117
# [150]	validation_0-mae:0.01117
# [200]	validation_0-mae:0.01117
# [250]	validation_0-mae:0.01117
# [300]	validation_0-mae:0.01116
# [350]	validation_0-mae:0.01117
# [400]	validation_0-mae:0.01117
# [450]	validation_0-mae:0.01116
# [499]	validation_0-mae:0.01117
# TS: 31
# Last Value SMAPE: 1.1258309832479911
# XGB SMAPE: 1.1128093376699026
# n_top: 7
# current smape: 1.1128093376699026
# best smape: 1.1136232718946462
# best_smape updated!
# feature_select...
# done
# tmp features: ['act_lag_2', 'pct_college', 'pct_it_workers', 'pct_bb', 'mbd_lag_1', 'pct_foreign_born', 'neighbor_average', 'median_hh_inc', 'act_lag_3']
# 29
# [0]	validation_0-mae:0.45135
# [50]	validation_0-mae:0.01315
# [100]	validation_0-mae:0.01090
# [150]	validation_0-mae:0.01094
# [200]	validation_0-mae:0.01095
# [250]	validation_0-mae:0.01096
# [300]	validation_0-mae:0.01097
# [350]	validation_0-mae:0.01097
# [400]	validation_0-mae:0.01097
# [450]	validation_0-mae:0.01097
# [499]	validation_0-mae:0.01098
# TS: 29
# Last Value SMAPE: 1.0868726017655663
# XGB SMAPE: 1.0951085716732263
# 30
# [0]	validation_0-mae:0.44530
# [50]	validation_0-mae:0.01202
# [100]	validation_0-mae:0.01313
# [150]	validation_0-mae:0.01320
# [200]	validation_0-mae:0.01320
# [250]	validation_0-mae:0.01320
# [300]	validation_0-mae:0.01320
# [350]	validation_0-mae:0.01320
# [400]	validation_0-mae:0.01320
# [450]	validation_0-mae:0.01321
# [499]	validation_0-mae:0.01321
# TS: 30
# Last Value SMAPE: 1.318087470449913
# XGB SMAPE: 1.3075386322411024
# 31
# [0]	validation_0-mae:0.45100
# [50]	validation_0-mae:0.01348
# [100]	validation_0-mae:0.01116
# [150]	validation_0-mae:0.01117
# [200]	validation_0-mae:0.01117
# [250]	validation_0-mae:0.01117
# [300]	validation_0-mae:0.01117
# [350]	validation_0-mae:0.01117
# [400]	validation_0-mae:0.01117
# [450]	validation_0-mae:0.01117
# [499]	validation_0-mae:0.01117
# TS: 31
# Last Value SMAPE: 1.1258309832479911
# XGB SMAPE: 1.1135413252284878
# n_top: 8
# current smape: 1.1135413252284878
# best smape: 1.1128093376699026
# feature_select...
# done
# tmp features: ['act_lag_2', 'pct_college', 'pct_it_workers', 'pct_bb', 'mbd_lag_1', 'pct_foreign_born', 'neighbor_average', 'median_hh_inc', 'act_lag_3', 'act_lag_1']
# 29
# [0]	validation_0-mae:0.45135
# [50]	validation_0-mae:0.01315
# [100]	validation_0-mae:0.01092
# [150]	validation_0-mae:0.01097
# [200]	validation_0-mae:0.01098
# [250]	validation_0-mae:0.01099
# [300]	validation_0-mae:0.01102
# [350]	validation_0-mae:0.01102
# [400]	validation_0-mae:0.01102
# [450]	validation_0-mae:0.01103
# [499]	validation_0-mae:0.01104
# TS: 29
# Last Value SMAPE: 1.0868726017655663
# XGB SMAPE: 1.1011852684803112
# 30
# [0]	validation_0-mae:0.44530
# [50]	validation_0-mae:0.01202
# [100]	validation_0-mae:0.01313
# [150]	validation_0-mae:0.01320
# [200]	validation_0-mae:0.01320
# [250]	validation_0-mae:0.01320
# [300]	validation_0-mae:0.01320
# [350]	validation_0-mae:0.01319
# [400]	validation_0-mae:0.01320
# [450]	validation_0-mae:0.01320
# [499]	validation_0-mae:0.01320
# TS: 30
# Last Value SMAPE: 1.318087470449913
# XGB SMAPE: 1.3069606733213075
# 31
# [0]	validation_0-mae:0.45100
# [50]	validation_0-mae:0.01350
# [100]	validation_0-mae:0.01116
# [150]	validation_0-mae:0.01116
# [200]	validation_0-mae:0.01116
# [250]	validation_0-mae:0.01116
# [300]	validation_0-mae:0.01116
# [350]	validation_0-mae:0.01116
# [400]	validation_0-mae:0.01116
# [450]	validation_0-mae:0.01116
# [499]	validation_0-mae:0.01116
# TS: 31
# Last Value SMAPE: 1.1258309832479911
# XGB SMAPE: 1.1123264151889003
# n_top: 9
# current smape: 1.1123264151889003
# best smape: 1.1128093376699026
# best_smape updated!
# feature_select...
# done
# tmp features: ['act_lag_2', 'pct_college', 'pct_it_workers', 'pct_bb', 'mbd_lag_1', 'pct_foreign_born', 'mbd_rollmea4_1', 'neighbor_average', 'median_hh_inc', 'act_lag_3', 'act_lag_1']
# 29
# [0]	validation_0-mae:0.45135
# [50]	validation_0-mae:0.01315
# [100]	validation_0-mae:0.01091
# [150]	validation_0-mae:0.01096
# [200]	validation_0-mae:0.01099
# [250]	validation_0-mae:0.01100
# [300]	validation_0-mae:0.01101
# [350]	validation_0-mae:0.01103
# [400]	validation_0-mae:0.01104
# [450]	validation_0-mae:0.01104
# [499]	validation_0-mae:0.01105
# TS: 29
# Last Value SMAPE: 1.0868726017655663
# XGB SMAPE: 1.1022302080848716
# 30
# [0]	validation_0-mae:0.44530
# [50]	validation_0-mae:0.01201
# [100]	validation_0-mae:0.01314
# [150]	validation_0-mae:0.01320
# [200]	validation_0-mae:0.01320
# [250]	validation_0-mae:0.01320
# [300]	validation_0-mae:0.01320
# [350]	validation_0-mae:0.01320
# [400]	validation_0-mae:0.01320
# [450]	validation_0-mae:0.01321
# [499]	validation_0-mae:0.01320
# TS: 30
# Last Value SMAPE: 1.318087470449913
# XGB SMAPE: 1.3074388508217374
# 31
# [0]	validation_0-mae:0.45100
# [50]	validation_0-mae:0.01350
# [100]	validation_0-mae:0.01116
# [150]	validation_0-mae:0.01116
# [200]	validation_0-mae:0.01117
# [250]	validation_0-mae:0.01117
# [300]	validation_0-mae:0.01117
# [350]	validation_0-mae:0.01116
# [400]	validation_0-mae:0.01116
# [450]	validation_0-mae:0.01116
# [499]	validation_0-mae:0.01117
# TS: 31
# Last Value SMAPE: 1.1258309832479911
# XGB SMAPE: 1.112745019405793
# n_top: 10
# current smape: 1.112745019405793
# best smape: 1.1123264151889003
# feature_select...
# done
# tmp features: ['act_lag_2', 'pct_college', 'pct_it_workers', 'pct_bb', 'mbd_lag_1', 'pct_foreign_born', 'mbd_rollmea4_1', 'neighbor_average', 'median_hh_inc', 'act_lag_3', 'act_lag_1', 'mbd_rollmea6_1']
# 29
# [0]	validation_0-mae:0.45135
# [50]	validation_0-mae:0.01310
# [100]	validation_0-mae:0.01091
# [150]	validation_0-mae:0.01097
# [200]	validation_0-mae:0.01099
# [250]	validation_0-mae:0.01102
# [300]	validation_0-mae:0.01103
# [350]	validation_0-mae:0.01104
# [400]	validation_0-mae:0.01105
# [450]	validation_0-mae:0.01106
# [499]	validation_0-mae:0.01108
# TS: 29
# Last Value SMAPE: 1.0868726017655663
# XGB SMAPE: 1.1050645985204994
# 30
# [0]	validation_0-mae:0.44530
# [50]	validation_0-mae:0.01202
# [100]	validation_0-mae:0.01314
# [150]	validation_0-mae:0.01321
# [200]	validation_0-mae:0.01321
# [250]	validation_0-mae:0.01322
# [300]	validation_0-mae:0.01322
# [350]	validation_0-mae:0.01322
# [400]	validation_0-mae:0.01322
# [450]	validation_0-mae:0.01322
# [499]	validation_0-mae:0.01322
# TS: 30
# Last Value SMAPE: 1.318087470449913
# XGB SMAPE: 1.308958071194355
# 31
# [0]	validation_0-mae:0.45100
# [50]	validation_0-mae:0.01349
# [100]	validation_0-mae:0.01119
# [150]	validation_0-mae:0.01120
# [200]	validation_0-mae:0.01120
# [250]	validation_0-mae:0.01120
# [300]	validation_0-mae:0.01120
# [350]	validation_0-mae:0.01120
# [400]	validation_0-mae:0.01121
# [450]	validation_0-mae:0.01121
# [499]	validation_0-mae:0.01121
# TS: 31
# Last Value SMAPE: 1.1258309832479911
# XGB SMAPE: 1.1172168317868594
# n_top: 11
# current smape: 1.1172168317868594
# best smape: 1.1123264151889003
# feature_select...
# done
# tmp features: ['act_lag_2', 'pct_college', 'pct_it_workers', 'pct_bb', 'mbd_lag_1', 'state_i', 'pct_foreign_born', 'mbd_rollmea4_1', 'neighbor_average', 'median_hh_inc', 'act_lag_3', 'act_lag_1', 'mbd_rollmea6_1']
# 29
# [0]	validation_0-mae:0.45135
# [50]	validation_0-mae:0.01312
# [100]	validation_0-mae:0.01095
# [150]	validation_0-mae:0.01099
# [200]	validation_0-mae:0.01101
# [250]	validation_0-mae:0.01103
# [300]	validation_0-mae:0.01104
# [350]	validation_0-mae:0.01105
# [400]	validation_0-mae:0.01106
# [450]	validation_0-mae:0.01106
# [499]	validation_0-mae:0.01107
# TS: 29
# Last Value SMAPE: 1.0868726017655663
# XGB SMAPE: 1.1045919640177604
# 30
# [0]	validation_0-mae:0.44530
# [50]	validation_0-mae:0.01202
# [100]	validation_0-mae:0.01313
# [150]	validation_0-mae:0.01320
# [200]	validation_0-mae:0.01320
# [250]	validation_0-mae:0.01320
# [300]	validation_0-mae:0.01321
# [350]	validation_0-mae:0.01320
# [400]	validation_0-mae:0.01321
# [450]	validation_0-mae:0.01321
# [499]	validation_0-mae:0.01321
# TS: 30
# Last Value SMAPE: 1.318087470449913
# XGB SMAPE: 1.3077299562690394
# 31
# [0]	validation_0-mae:0.45100
# [50]	validation_0-mae:0.01349
# [100]	validation_0-mae:0.01118
# [150]	validation_0-mae:0.01120
# [200]	validation_0-mae:0.01120
# [250]	validation_0-mae:0.01120
# [300]	validation_0-mae:0.01120
# [350]	validation_0-mae:0.01121
# [400]	validation_0-mae:0.01121
# [450]	validation_0-mae:0.01120
# [499]	validation_0-mae:0.01120
# TS: 31
# Last Value SMAPE: 1.1258309832479911
# XGB SMAPE: 1.1165912848479063
# n_top: 12
# current smape: 1.1165912848479063
# best smape: 1.1123264151889003
# feature_select...
# done
# tmp features: ['act_lag_2', 'pct_college', 'pct_it_workers', 'pct_bb', 'mbd_lag_1', 'mbd_rollmea2_1', 'state_i', 'pct_foreign_born', 'mbd_rollmea4_1', 'neighbor_average', 'median_hh_inc', 'act_lag_3', 'act_lag_1', 'mbd_rollmea6_1']
# 29
# [0]	validation_0-mae:0.45135
# [50]	validation_0-mae:0.01314
# [100]	validation_0-mae:0.01093
# [150]	validation_0-mae:0.01099
# [200]	validation_0-mae:0.01100
# [250]	validation_0-mae:0.01102
# [300]	validation_0-mae:0.01103
# [350]	validation_0-mae:0.01104
# [400]	validation_0-mae:0.01105
# [450]	validation_0-mae:0.01106
# [499]	validation_0-mae:0.01106
# TS: 29
# Last Value SMAPE: 1.0868726017655663
# XGB SMAPE: 1.1032521467261298
# 30
# [0]	validation_0-mae:0.44530
# [50]	validation_0-mae:0.01201
# [100]	validation_0-mae:0.01314
# [150]	validation_0-mae:0.01320
# [200]	validation_0-mae:0.01319
# [250]	validation_0-mae:0.01319
# [300]	validation_0-mae:0.01319
# [350]	validation_0-mae:0.01318
# [400]	validation_0-mae:0.01318
# [450]	validation_0-mae:0.01319
# [499]	validation_0-mae:0.01318
# TS: 30
# Last Value SMAPE: 1.318087470449913
# XGB SMAPE: 1.3050629954057127
# 31
# [0]	validation_0-mae:0.45100
# [50]	validation_0-mae:0.01348
# [100]	validation_0-mae:0.01119
# [150]	validation_0-mae:0.01120
# [200]	validation_0-mae:0.01121
# [250]	validation_0-mae:0.01121
# [300]	validation_0-mae:0.01121
# [350]	validation_0-mae:0.01122
# [400]	validation_0-mae:0.01122
# [450]	validation_0-mae:0.01122
# [499]	validation_0-mae:0.01122
# TS: 31
# Last Value SMAPE: 1.1258309832479911
# XGB SMAPE: 1.1184075925913675
# n_top: 13
# current smape: 1.1184075925913675
# best smape: 1.1123264151889003
# feature_select...
# done
# tmp features: ['act_lag_2', 'pct_college', 'pct_it_workers', 'pct_bb', 'mbd_lag_1', 'mbd_rollmea2_1', 'state_i', 'pct_foreign_born', 'mbd_rollmea4_1', 'neighbor_average', 'median_hh_inc', 'act_lag_3', 'act_lag_1', 'mbd_rollmea6_1']
# 29
# [0]	validation_0-mae:0.45135
# [50]	validation_0-mae:0.01314
# [100]	validation_0-mae:0.01093
# [150]	validation_0-mae:0.01099
# [200]	validation_0-mae:0.01100
# [250]	validation_0-mae:0.01102
# [300]	validation_0-mae:0.01103
# [350]	validation_0-mae:0.01104
# [400]	validation_0-mae:0.01105
# [450]	validation_0-mae:0.01106
# [499]	validation_0-mae:0.01106
# TS: 29
# Last Value SMAPE: 1.0868726017655663
# XGB SMAPE: 1.1032521467261298
# 30
# [0]	validation_0-mae:0.44530
# [50]	validation_0-mae:0.01201
# [100]	validation_0-mae:0.01314
# [150]	validation_0-mae:0.01320
# [200]	validation_0-mae:0.01319
# [250]	validation_0-mae:0.01319
# [300]	validation_0-mae:0.01319
# [350]	validation_0-mae:0.01318
# [400]	validation_0-mae:0.01318
# [450]	validation_0-mae:0.01319
# [499]	validation_0-mae:0.01318
# TS: 30
# Last Value SMAPE: 1.318087470449913
# XGB SMAPE: 1.3050629954057127
# 31
# [0]	validation_0-mae:0.45100
# [50]	validation_0-mae:0.01348
# [100]	validation_0-mae:0.01119
# [150]	validation_0-mae:0.01120
# [200]	validation_0-mae:0.01121
# [250]	validation_0-mae:0.01121
# [300]	validation_0-mae:0.01121
# [350]	validation_0-mae:0.01122
# [400]	validation_0-mae:0.01122
# [450]	validation_0-mae:0.01122
# [499]	validation_0-mae:0.01122
# TS: 31
# Last Value SMAPE: 1.1258309832479911
# XGB SMAPE: 1.1184075925913675
# n_top: 14
# current smape: 1.1184075925913675
# best smape: 1.1123264151889003
# feature_select...
# done
# tmp features: ['act_lag_2', 'pct_college', 'pct_it_workers', 'pct_bb', 'mbd_lag_1', 'mbd_rollmea2_1', 'state_i', 'pct_foreign_born', 'mbd_rollmea4_1', 'neighbor_average', 'median_hh_inc', 'act_lag_3', 'mbd_lag_2', 'act_lag_1', 'mbd_rollmea6_1']
# 29
# [0]	validation_0-mae:0.45135
# [50]	validation_0-mae:0.01312
# [100]	validation_0-mae:0.01093
# [150]	validation_0-mae:0.01098
# [200]	validation_0-mae:0.01099
# [250]	validation_0-mae:0.01101
# [300]	validation_0-mae:0.01101
# [350]	validation_0-mae:0.01102
# [400]	validation_0-mae:0.01103
# [450]	validation_0-mae:0.01103
# [499]	validation_0-mae:0.01104
# TS: 29
# Last Value SMAPE: 1.0868726017655663
# XGB SMAPE: 1.1013021167527361
# 30
# [0]	validation_0-mae:0.44530
# [50]	validation_0-mae:0.01202
# [100]	validation_0-mae:0.01310
# [150]	validation_0-mae:0.01316
# [200]	validation_0-mae:0.01316
# [250]	validation_0-mae:0.01316
# [300]	validation_0-mae:0.01316
# [350]	validation_0-mae:0.01316
# [400]	validation_0-mae:0.01317
# [450]	validation_0-mae:0.01317
# [499]	validation_0-mae:0.01316
# TS: 30
# Last Value SMAPE: 1.318087470449913
# XGB SMAPE: 1.3028987039897761
# 31
# [0]	validation_0-mae:0.45100
# [50]	validation_0-mae:0.01349
# [100]	validation_0-mae:0.01119
# [150]	validation_0-mae:0.01121
# [200]	validation_0-mae:0.01121
# [250]	validation_0-mae:0.01121
# [300]	validation_0-mae:0.01122
# [350]	validation_0-mae:0.01122
# [400]	validation_0-mae:0.01122
# [450]	validation_0-mae:0.01122
# [499]	validation_0-mae:0.01123
# TS: 31
# Last Value SMAPE: 1.1258309832479911
# XGB SMAPE: 1.1187813079511484
# n_top: 15
# current smape: 1.1187813079511484
# best smape: 1.1123264151889003
# feature_select...
# done
# tmp features: ['act_lag_2', 'pct_college', 'pct_it_workers', 'pct_bb', 'mbd_lag_1', 'mbd_rollmea2_1', 'state_i', 'pct_foreign_born', 'mbd_rollmea4_1', 'mbd_lag_3', 'neighbor_average', 'median_hh_inc', 'act_lag_3', 'mbd_lag_2', 'act_lag_1', 'mbd_rollmea6_1']
# 29
# [0]	validation_0-mae:0.45135
# [50]	validation_0-mae:0.01309
# [100]	validation_0-mae:0.01094
# [150]	validation_0-mae:0.01097
# [200]	validation_0-mae:0.01098
# [250]	validation_0-mae:0.01101
# [300]	validation_0-mae:0.01102
# [350]	validation_0-mae:0.01103
# [400]	validation_0-mae:0.01105
# [450]	validation_0-mae:0.01106
# [499]	validation_0-mae:0.01106
# TS: 29
# Last Value SMAPE: 1.0868726017655663
# XGB SMAPE: 1.102944427163317
# 30
# [0]	validation_0-mae:0.44530
# [50]	validation_0-mae:0.01202
# [100]	validation_0-mae:0.01311
# [150]	validation_0-mae:0.01316
# [200]	validation_0-mae:0.01316
# [250]	validation_0-mae:0.01316
# [300]	validation_0-mae:0.01315
# [350]	validation_0-mae:0.01315
# [400]	validation_0-mae:0.01315
# [450]	validation_0-mae:0.01315
# [499]	validation_0-mae:0.01315
# TS: 30
# Last Value SMAPE: 1.318087470449913
# XGB SMAPE: 1.302101542243318
# 31
# [0]	validation_0-mae:0.45100
# [50]	validation_0-mae:0.01349
# [100]	validation_0-mae:0.01119
# [150]	validation_0-mae:0.01120
# [200]	validation_0-mae:0.01120
# [250]	validation_0-mae:0.01120
# [300]	validation_0-mae:0.01120
# [350]	validation_0-mae:0.01120
# [400]	validation_0-mae:0.01120
# [450]	validation_0-mae:0.01120
# [499]	validation_0-mae:0.01120
# TS: 31
# Last Value SMAPE: 1.1258309832479911
# XGB SMAPE: 1.1160415579716148
# n_top: 16
# current smape: 1.1160415579716148
# best smape: 1.1123264151889003

# %%
best_smape
# Out:
# 1.0623562196689202

# %%
raw, features = feature_select_pearson(raw, features, best_n_top)
# Out:
# feature_select...
# done

# %%
raw
# Out:
#                   row_id  cfips          county    state first_day_of_month  \
# 0        1001_2019-08-01   1001  Autauga County  Alabama         2019-08-01
# 1        1001_2019-09-01   1001  Autauga County  Alabama         2019-09-01
# 2        1001_2019-10-01   1001  Autauga County  Alabama         2019-10-01
# 3        1001_2019-11-01   1001  Autauga County  Alabama         2019-11-01
# 4        1001_2019-12-01   1001  Autauga County  Alabama         2019-12-01
# ...                  ...    ...             ...      ...                ...
# 147340  56045_2023-02-01  56045   Weston County  Wyoming         2023-02-01
# 147341  56045_2023-03-01  56045   Weston County  Wyoming         2023-03-01
# 147342  56045_2023-04-01  56045   Weston County  Wyoming         2023-04-01
# 147343  56045_2023-05-01  56045   Weston County  Wyoming         2023-05-01
# 147344  56045_2023-06-01  56045   Weston County  Wyoming         2023-06-01
#
#         microbusiness_density  active  istest  year  month  ...  act_lag_2  \
# 0                    2.856021  1249.0       0  2019      8  ...        NaN
# 1                    2.884870  1198.0       0  2019      9  ...        NaN
# 2                    3.055843  1269.0       0  2019     10  ...       20.0
# 3                    2.993233  1243.0       0  2019     11  ...       45.0
# 4                    2.993233  1243.0       0  2019     12  ...      -26.0
# ...                       ...     ...     ...   ...    ...  ...        ...
# 147340                    NaN     NaN       1  2023      2  ...        NaN
# 147341                    NaN     NaN       1  2023      3  ...        NaN
# 147342                    NaN     NaN       1  2023      4  ...        NaN
# 147343                    NaN     NaN       1  2023      5  ...        NaN
# 147344                    NaN     NaN       1  2023      6  ...        NaN
#
#         act_lag_3  mbd_rollmea4_1  mbd_rollmea6_1  neighbor_average  pct_bb  \
# 0             NaN             NaN             NaN            2157.8      80
# 1             NaN        0.010101        0.010101            2161.6      80
# 2             NaN        0.069366        0.069366            2158.4      80
# 3            -6.0        0.048878        0.048878            2150.0      80
# 4            45.0        0.048878        0.048878            2215.4      80
# ...           ...             ...             ...               ...     ...
# 147340        NaN             NaN        0.000000               NaN      81
# 147341        NaN             NaN        0.000000               NaN      81
# 147342        NaN             NaN             NaN               NaN      81
# 147343        NaN             NaN             NaN               NaN      81
# 147344        NaN             NaN             NaN               NaN      81
#
#         pct_college  pct_foreign_born  pct_it_workers  median_hh_inc
# 0                16                 2               0          58731
# 1                16                 2               0          58731
# 2                16                 2               0          58731
# 3                16                 2               0          58731
# 4                16                 2               0          58731
# ...             ...               ...             ...            ...
# 147340           13                 1               0          65566
# 147341           13                 1               0          65566
# 147342           13                 1               0          65566
# 147343           13                 1               0          65566
# 147344           13                 1               0          65566
#
# [147345 rows x 28 columns]

# %%
features
# Out:
# ['pct_college',
#  'act_lag_3',
#  'pct_bb',
#  'mbd_rollmea6_1',
#  'pct_foreign_born',
#  'median_hh_inc',
#  'pct_it_workers',
#  'act_lag_2',
#  'act_lag_1',
#  'mbd_rollmea4_1',
#  'mbd_lag_1',
#  'neighbor_average']

# %%
ACT_THR = 1.8
ABS_THR = 1.00
raw['ypred_last'] = np.nan
raw['ypred'] = np.nan
raw['k'] = 1.
VAL = []
BEST_ROUNDS = []
for TS in range(29, 38):
    print(TS)
    
    model = xgb.XGBRegressor(
        objective='reg:pseudohubererror',
        #objective='reg:squarederror',
        tree_method="hist",
        n_estimators=4999,
        learning_rate=0.0075,
        max_leaves = 17,
        subsample=0.50,
        colsample_bytree=0.50,
        max_bin=4096,
        n_jobs=2,
        eval_metric='mae',
        early_stopping_rounds=70,
    )
            
    train_indices = (raw.istest==0) & (raw.dcount  < TS) & (raw.dcount >= 1) & (raw.lastactive>ACT_THR)  & (raw.lasttarget>ABS_THR) 
    valid_indices = (raw.istest==0) & (raw.dcount == TS)
    model.fit(
        raw.loc[train_indices, features],
        raw.loc[train_indices, 'target'].clip(-0.0043, 0.0045),
        eval_set=[(raw.loc[valid_indices, features], raw.loc[valid_indices, 'target'])],
        verbose=500,
    )
    best_rounds = model.best_iteration
    BEST_ROUNDS.append(model.best_iteration)
    ypred = model.predict(raw.loc[valid_indices, features])
    raw.loc[valid_indices, 'k'] = ypred + 1
    raw.loc[valid_indices,'k'] = raw.loc[valid_indices,'k'] * raw.loc[valid_indices,'microbusiness_density']

    # Validate
    lastval = raw.loc[raw.dcount==TS, ['cfips', 'microbusiness_density']].set_index('cfips').to_dict()['microbusiness_density']
    dt = raw.loc[raw.dcount==TS, ['cfips', 'k']].set_index('cfips').to_dict()['k']
    
    df = raw.loc[raw.dcount==(TS+1), ['cfips', 'microbusiness_density', 'state', 'lastactive', 'mbd_lag_1']].reset_index(drop=True)
    df['pred'] = df['cfips'].map(dt)
    df['lastval'] = df['cfips'].map(lastval)
    
    df.loc[df['lastactive']<=ACT_THR, 'pred'] = df.loc[df['lastactive']<=ACT_THR, 'lastval']
    df.loc[df['lastval']<=ABS_THR, 'pred'] = df.loc[df['lastval']<=ABS_THR, 'lastval']
    raw.loc[raw.dcount==(TS+1), 'ypred'] = df['pred'].values
    raw.loc[raw.dcount==(TS+1), 'ypred_last'] = df['lastval'].values
    
    print(f'TS: {TS}')
    print('Last Value SMAPE:', smape(df['microbusiness_density'], df['lastval']) )
    print('XGB SMAPE:', smape(df['microbusiness_density'], df['pred']))
    print()


ind = (raw.dcount>=30)&(raw.dcount<=38)
print( 'XGB SMAPE:', smape( raw.loc[ind, 'microbusiness_density'],  raw.loc[ind, 'ypred'] ) )
print( 'Last Value SMAPE:', smape( raw.loc[ind, 'microbusiness_density'],  raw.loc[ind, 'ypred_last'] ) )
# Out:
# 29
# [0]	validation_0-mae:0.49351
# [500]	validation_0-mae:0.01429
# [897]	validation_0-mae:0.01091
# TS: 29
# Last Value SMAPE: 1.0868726017655663
# XGB SMAPE: 1.0738047669774673
#
# 30
# [0]	validation_0-mae:0.48746
# [500]	validation_0-mae:0.01256
# [641]	validation_0-mae:0.01206
# TS: 30
# Last Value SMAPE: 1.318087470449913
# XGB SMAPE: 1.1474297430595695
#
# 31
# [0]	validation_0-mae:0.49315
# [500]	validation_0-mae:0.01466
# [923]	validation_0-mae:0.01118
# TS: 31
# Last Value SMAPE: 1.1258309832479911
# XGB SMAPE: 1.1055844960714658
#
# 32
# [0]	validation_0-mae:0.49995
# [500]	validation_0-mae:0.01702
# [1000]	validation_0-mae:0.00928
# [1500]	validation_0-mae:0.00913
# [1897]	validation_0-mae:0.00913
# TS: 32
# Last Value SMAPE: 0.897969439640235
# XGB SMAPE: 0.9101787950611636
#
# 33
# [0]	validation_0-mae:0.48932
# [500]	validation_0-mae:0.01450
# [681]	validation_0-mae:0.01329
# TS: 33
# Last Value SMAPE: 1.3686285670946152
# XGB SMAPE: 1.2613709283532193
#
# 34
# [0]	validation_0-mae:0.47751
# [500]	validation_0-mae:0.01611
# [509]	validation_0-mae:0.01638
# TS: 34
# Last Value SMAPE: 2.2033066808448543
# XGB SMAPE: 1.6184248103914038
#
# 35
# [0]	validation_0-mae:0.50121
# [500]	validation_0-mae:0.02041
# [1000]	validation_0-mae:0.01325
# [1500]	validation_0-mae:0.01312
# [1649]	validation_0-mae:0.01312
# TS: 35
# Last Value SMAPE: 1.2797936949214384
# XGB SMAPE: 1.302455347225088
#
# 36
# [0]	validation_0-mae:0.49246
# [500]	validation_0-mae:0.01326
# [797]	validation_0-mae:0.01027
# TS: 36
# Last Value SMAPE: 1.034314865882525
# XGB SMAPE: 0.9938107137214037
#
# 37
# [0]	validation_0-mae:0.49470
# [500]	validation_0-mae:0.01631
# [838]	validation_0-mae:0.01294
# TS: 37
# Last Value SMAPE: 1.101119095956366
# XGB SMAPE: 1.0623562196689202
#
# XGB SMAPE: 1.1639350911699669
# Last Value SMAPE: 1.2684359333115005

# %%
# Prediction
raw['error'] = vsmape(raw['microbusiness_density'], raw['ypred'])
raw['error_last'] = vsmape(raw['microbusiness_density'], raw['ypred_last'])
raw.loc[(raw.dcount==30), ['microbusiness_density', 'ypred', 'error', 'error_last'] ]
# Out:
#         microbusiness_density      ypred     error  error_last
# 30                   3.334431   3.300729  1.015863    1.135557
# 77                   7.823300   7.738336  1.091972    1.155810
# 124                  1.206827   1.187959  1.575711    1.687769
# 171                  1.236650   1.215709  1.707845    1.834867
# 218                  1.777708   1.754112  1.336190    1.403959
# ...                       ...        ...       ...         ...
# 147140               2.892446   2.926768  1.179620    1.179620
# 147187              25.438322  25.551003  0.441979    0.368550
# 147234               3.954258   3.757571  5.100897    5.183206
# 147281               3.027295   3.027295  0.000000    0.000000
# 147328               1.749688   1.749688  0.000000    0.000000
#
# [3135 rows x 4 columns]
